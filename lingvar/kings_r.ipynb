# %%
data = read.table(
    'new_matrix.tsv', 
    sep="\t", 
    header=TRUE, 
    comment.char="",
    quote="",
    as.is = FALSE,
)
rownames(data) = data[, 1]
data[, 1] = NULL
dim(data)
head(data)
# Out:
# [1] 265 265
#               Reges_I.11.41 Reges_I.14.29 Reges_I.15.7 Reges_I.15.31
# Reges_I.11.41             0             0            0             0
# Reges_I.14.29             0             0            0             0
# Reges_I.15.7              0             0            0             0
# Reges_I.15.31             0             0            0             0
# Reges_I.16.5              0             0            0             0
# Reges_I.16.14             0             0            0             0
#               Reges_I.16.5 Reges_I.16.14 Reges_I.16.20 Reges_I.16.27
# Reges_I.11.41            0             0             0             0
# Reges_I.14.29            0             0             0             0
# Reges_I.15.7             0             0             0             0
# Reges_I.15.31            0             0             0             0
# Reges_I.16.5             0             0             0             0
# ...

# %%
REPO = 'http://cran.us.r-project.org'
#install.packages('gplots', repos=REPO)
install.packages('lattice', repos=REPO)
# Out:
# Warning message:
# In install.packages("lattice", repos = REPO): installation of package ‘lattice’ had non-zero exit status
# The downloaded source packages are in
# 	‘/private/var/folders/mr/v68m5kjn375c46fmlw70r4wh0000gn/T/RtmpOyRtnL/downloaded_packages’
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
require(gplots)

# %%
library(lattice)

# %%
levelplot(as.matrix(data))
# Out:
# plot without title

# %%
help(heatmap.2)
# Out:
# heatmap.2                package:gplots                R Documentation
#
# p
#
# n:
#
#      A heat map is a false color image (basically ‘image(t(x))’) with a
#      dendrogram added to the left side and/or to the top.  Typically,
#      reordering of the rows and columns according to some set of values
#      (row or column means) within the restrictions imposed by the
#      dendrogram is carried out.
#
#      This heatmap provides a number of extensions to the standard R
#      ‘heatmap’ function.
#
# e:
#
#      heatmap.2 (x,
#
#                 # dendrogram control
#                 Rowv = TRUE,
#                 Colv=if(symm)"Rowv" else TRUE,
#                 distfun = dist,
#                 hclustfun = hclust,
#                 dendrogram = c("both","row","column","none"),
#                 reorderfun = function(d, w) reorder(d, w),
#                 symm = FALSE,
#
#                 # data scaling
#                 scale = c("none","row", "column"),
# ...

# %%
data = read.table(
    'these_crossrefs.ncol', 
    sep="\t", 
    header=FALSE, 
    comment.char="",
    quote="",
    as.is = FALSE,
)

# %%
dim(data)
head(data)
# Out:
# [1] 250   2
#                           V1  V2
# 1 Reges_IIr.19.1-Jesaia.37.1 100
# 2 Reges_IIr.19.2-Jesaia.37.2  92
# 3 Reges_IIr.19.3-Jesaia.37.3 100
# 4 Reges_IIr.19.4-Jesaia.37.4  99
# 5 Reges_IIr.19.5-Jesaia.37.5 100
# 6 Reges_IIr.19.6-Jesaia.37.6 100

# %%
barplot(data$V2)
# Out:
# plot without title

# %%
help(barplot)
# Out:
# barplot                package:graphics                R Documentation
#
# s
#
# n:
#
#      Creates a bar plot with vertical or horizontal bars.
#
# e:
#
#      barplot(height, ...)
#
#      ## Default S3 method:
#      barplot(height, width = 1, space = NULL,
#              names.arg = NULL, legend.text = NULL, beside = FALSE,
#              horiz = FALSE, density = NULL, angle = 45,
#              col = NULL, border = par("fg"),
#              main = NULL, sub = NULL, xlab = NULL, ylab = NULL,
#              xlim = NULL, ylim = NULL, xpd = TRUE, log = "",
#              axes = TRUE, axisnames = TRUE,
#              cex.axis = par("cex.axis"), cex.names = par("cex.axis"),
#              inside = TRUE, plot = TRUE, axis.lty = 0, offset = 0,
#              add = FALSE, args.legend = NULL, ...)
#
# s:
#
#   height: either a vector or matrix of values describing the bars which
#           make up the plot.  If ‘height’ is a vector, the plot consists
# ...
