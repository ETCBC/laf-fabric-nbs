# %% [markdown]
# <a href="http://laf-fabric.readthedocs.org/en/latest/" target="_blank"><img align="left" src="images/laf-fabric-small.png"/></a>
# <a href="https://shebanq.ancient-data.org" target="_blank"><img align="left"src="images/shebanq_logo_small.png"/></a>
# <a href="http://dx.doi.org/10.17026/dans-z6y-skyh" target="_blank"><img align="left"src="images/DANS-logo_small.png"/></a>
# <a href="https://www.dbg.de/index.php?L=1" target="_blank"><img align="right" src="images/DBG-small.png"/></a>
# <a href="http://www.godgeleerdheid.vu.nl/etcbc" target="_blank"><img align="right" src="images/VU-ETCBC-small.png"/></a>

# %% [markdown]
# # Topic analysis
#
# Joint work of Mathias Coeckelbergs and Dirk Roorda.
#
# Mathias is experimenting with topic detection experiments using Mallet
# Dirk and Mathias integrate results of those experiments in the Hebrew text.
#
# We are still in a preliminary stage (2016-03-15).
#
# Basically, we render the Hebrew text, but add a hyperlink to each word that is part of a topic definition. The hyperlink points to the corresponding topic.
#
# # Result
#
# [Full hyperlinked text](etcbc_topictext.html) (5.7 MB)

# %%
import sys, collections, re
from markdown import markdown

from laf.fabric import LafFabric
from etcbc.preprocess import prepare
fabric = LafFabric()
# Out:
#   0.00s This is LAF-Fabric 4.5.22
# API reference: http://laf-fabric.readthedocs.org/en/latest/texts/API-reference.html
# Feature doc: https://shebanq.ancient-data.org/static/docs/featuredoc/texts/welcome.html

# %%
source='etcbc'
version='4b'

# %%
API=fabric.load(source+version, 'lexicon', 'workshop', {
    "xmlids": {"node": False, "edge": False},
    "features": ('''
        otype
        lex
        sp gloss
        chapter verse
    ''',''),
    "prepare": prepare,
    "primary": False,
})
exec(fabric.localnames.format(var='fabric'))
# Out:
#   0.00s LOADING API: please wait ...
#   0.00s USING main  DATA COMPILED AT: 2015-11-02T15-08-56
#   0.00s USING annox DATA COMPILED AT: 2016-01-27T19-01-17
#   2.45s LOGFILE=/Users/dirk/laf-fabric-output/etcbc4b/workshop/__log__workshop.txt
#   2.45s INFO: LOADING PREPARED data: please wait ...
#   2.45s prep prep: G.node_sort
#   2.57s prep prep: G.node_sort_inv
#   3.07s prep prep: L.node_up
#   6.82s prep prep: L.node_down
#     12s prep prep: V.verses
#     12s prep prep: V.books_la
#     12s ETCBC reference: http://laf-fabric.readthedocs.org/en/latest/texts/ETCBC-reference.html
#     14s INFO: LOADED PREPARED data
#     14s INFO: DATA LOADED FROM SOURCE etcbc4b AND ANNOX lexicon FOR TASK workshop AT 2016-03-14T22-37-41

# %% [markdown]
# # Topic compilation
#
# We compile the list of topics, produced by Mallet, into a dictionary with topic words as keys, and sets of topics as values.

# %%
word2topic = collections.defaultdict(set)
topic2words = {}
keys = open('etcbc_keys.txt')
for line in keys:
    (n, r, words) = line.rstrip().split('\t')
    n = int(n)
    word_list = words.split()
    for word in word_list:
        word2topic[word].add(n)
    topic2words[n] = word_list

# %% [markdown]
# Here is the resulting mapping.

# %%
word2topic
# Out:
# defaultdict(set,
#             {'ba[yhwˈāh': {14},
#              'bammˈāyim': {16},
#              'bayyˈôm': {3},
#              'baššānˈā': {9},
#              'baḥˈerev': {11},
#              'bišᵊnˈaṯ': {9},
#              'bānˈîm': {4},
#              'bāvˈel': {5},
#              'bāśˈār': {0},
#              'bēʔḏˈayin': {14},
#              'bˈêṯ': {17},
#              'bˈêṯ-ʔˈēl': {14},
#              'bˈānû': {0},
#              'bˈāʔû': {1},
#              'bᵊhˌar': {9},
#              'bᵊmālᵊḵˈô': {1},
#              'bᵊnˈê': {17},
#              'bᵊnˌê': {15},
#              'bᵊnˌô': {12},
#              'bᵊrîṯ-[yᵊhwˈāh': {7},
#              'bᵊʕênˈê': {18},
#              'bᵊḵˌōl': {2},
#              'dāwˈiḏ': {17},
#              'dāwˌîḏ': {16},
#              'dˌî': {12},
#              'fᵊlištˈîm': {18},
#              'gˈam': {8},
#              'gˌam': {4},
#              'gᵊvˈûl': {0},
#              'haddāvˈār': {15},
#              'haddᵊvārˈîm': {1},
# ...

# %% [markdown]
# Just to explore: are there words that belong to multiple topics?

# %%
multiples = {x for x in word2topic if len(word2topic[x]) > 1}
len(multiples)
# Out:
# 9

# %% [markdown]
# Yes, and here they are:

# %%
multiples
# Out:
# {'laʕᵃśˌôṯ',
#  'llēʔmˈōr',
#  'lˈî',
#  'malkˈā',
#  'wayyiqrˌā',
#  'wayᵊhˈî',
#  'ʔᵉlōhˌîm',
#  'ʕal-kˈēn',
#  'ʕôlˈām'}

# %% [markdown]
# Write a HTML file of topics.

# %%
topic2words
# Out:
# {0: ['ʕāśˌû',
#   'gᵊvˈûl',
#   'hāʔᵃnāšˈîm',
#   'taʕᵃśˈeh',
#   'ʔavšālˈôm',
#   'ʔᵃlēhˌem',
#   'yᵊmˌê',
#   'waḥᵃmiššˈā',
#   'ʔārˈûr',
#   'ʔaḥʔˌāv',
#   'ʔāsˈā',
#   'hōlˈēḵ',
#   'qoḏšˈî',
#   'waʕᵃśîṯˌem',
#   'māḡˈēn',
#   'bˈānû',
#   'sˈōleṯ',
#   'šᵊʔērˈîṯ',
#   'ʔˌēṣel',
#   'bāśˈār'],
#  1: ['ʕôlˈām',
#   'bˈāʔû',
#   'haddᵊvārˈîm',
#   'wᵊʔahᵃrˈōn',
#   'pᵊnˌê',
#   'šōmᵊrˈôn',
#   'qˌôl',
#   'rˈāv',
#   'šᵊnˈê',
#   'hayyardˌēn',
#   'wayyimlˌōḵ',
#   'šivʕˌā',
#   'rāʕˈā',
#   'lāḏˈaʕaṯ',
#   'haṭṭˈôv',
#   'ʕal-hammizbˌēₐḥ',
#   'ʔel-ʔˈōhel',
#   'ḏāwˈîḏ',
#   'bᵊmālᵊḵˈô',
#   'ḥˈāyil'],
#  2: ['ʔᵃḏōnˈāy',
#   'ʔeḥˈāḏ',
#   'lˈî',
#   'miṣrˈayim',
#   'ʕāśˌār',
#   'wᵊḵˌōl',
#   'hannāvˈî',
#   'yāmˌîm',
#   'bᵊḵˌōl',
#   'wᵊʕāśˈîṯā',
#   'yāḏˌô',
#   'laʕᵃśˌôṯ',
#   'hahˈî',
#   'šivʕˈaṯ',
#   'ʕal-kˈēn',
#   'ʕāśˈîṯā',
#   'nāṯˌan',
#   'ʔᵃnˈaḥnû',
#   'rāʔˈîṯî',
#   'wᵊʔattˌem'],
#  3: ['kˈî',
#   'ʔᵃšˈer',
#   'yiśrāʔˈēl',
#   'hazzˈeh',
#   'ʔˈîš',
# ...

# %%
filename = 'topic_list.html'
with open(filename, 'w') as f:
    f.write('''
<html>
<body>
''')
    for (t, words) in sorted(topic2words.items()):
        f.write('''
<h3><a name="topic_{}">Topic {}</a></h3>
<p>{}</p>
'''.format(t, t, '<br/>'.join(words)))
    f.write('''
</body>
</html>
''')

# %% [markdown]
# # Producing a text
#
# We produce a phonemic Hebrew Bible in markdown syntax.

# %%
msg('Writing Bible in markdown')
filename = 'etcbc_topictext.html'
md_lines = []
for v in F.otype.s('verse'):
    b = L.u('book', v)
    book = T.book_name(b)
    chapter = F.chapter.v(v)
    verse = F.verse.v(v)
    label = '{} {}:{}'.format(book, chapter, verse)
    line = []
    for w in L.d('word', v):
        word = T.words([w], fmt='pf')
        word_lookup = word.rstrip()
        topics = word2topic.get(word_lookup, [])
        topic_refs = ' '.join(
            '[{}](topics.html#topic_{})'.format(topic, topic) for topic in topics
        )
        line.append('{}{}'.format(topic_refs, word))
    md_lines.append('{} {}'.format(label, ''.join(line)))
msg('Converting markdown to html')
tf = open(filename, 'w')
tf.write('''<html>
<body>
{}
</body>
</html>
'''.format(markdown('\n'.join(md_lines))))
tf.close()
msg('Done')
# Out:
# 31m 38s Writing Bible in markdown
# 31m 41s Converting markdown to html
# 31m 52s Done
